# %% [markdown]
# <a href="https://colab.research.google.com/github/ss21462/CE888/blob/main/employee%20satisfaction%20index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
from imblearn.datasets import make_imbalance

# %%
from google.colab import files
u=files.upload()
# Out:
#      <input type="file" id="files-6ae5f7a2-3a0e-4ff6-9e46-bd9198fb81d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ae5f7a2-3a0e-4ff6-9e46-bd9198fb81d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Employee Satisfaction Index.csv to Employee Satisfaction Index (1).csv

# %%
import pandas as pd
df=pd.read_csv('/content/Employee Satisfaction Index.csv')
df
# Out:
#      Unnamed: 0    emp_id  age  ... certifications salary satisfied
# 0             0    HR8270   28  ...              0  86750         1
# 1             1  TECH1860   50  ...              1  42419         0
# 2             2  TECH6390   43  ...              0  65715         0
# 3             3   SAL6191   44  ...              0  29805         1
# 4             4    HR6734   33  ...              0  29805         1
# ..          ...       ...  ...  ...            ...    ...       ...
# 495         495    HR5330   49  ...              0  29805         1
# 496         496  TECH9010   24  ...              0  29805         0
# 497         497   MKT7801   34  ...              0  24076         1
# 498         498  TECH5846   26  ...              1  29805         0
# 499         499  TECH7731   26  ...              0  42419         0
#
# [500 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        500 non-null    int64
#  1   emp_id            500 non-null    object
#  2   age               500 non-null    int64
#  3   Dept              500 non-null    object
#  4   location          500 non-null    object
#  5   education         500 non-null    object
#  6   recruitment_type  500 non-null    object
#  7   job_level         500 non-null    int64
#  8   rating            500 non-null    int64
#  9   onsite            500 non-null    int64
#  10  awards            500 non-null    int64
#  11  certifications    500 non-null    int64
#  12  salary            500 non-null    int64
#  13  satisfied         500 non-null    int64
# dtypes: int64(9), object(5)
# memory usage: 54.8+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# emp_id              object
# age                  int64
# Dept                object
# location            object
# education           object
# recruitment_type    object
# job_level            int64
# rating               int64
# onsite               int64
# awards               int64
# certifications       int64
# salary               int64
# satisfied            int64
# dtype: object

# %%
print ('number of rows before dropping NaNS')
print(len(df))
df=df.dropna()
print ('number of rows after dropping NaNS')
print(len(df))
# Out:
# number of rows before dropping NaNS
# 500
# number of rows after dropping NaNS
# 500

# %%
df = pd.get_dummies(df)
df
# Out:
#      Unnamed: 0  age  ...  recruitment_type_Referral  recruitment_type_Walk-in
# 0             0   28  ...                          1                         0
# 1             1   50  ...                          0                         1
# 2             2   43  ...                          1                         0
# 3             3   44  ...                          0                         0
# 4             4   33  ...                          0                         0
# ..          ...  ...  ...                        ...                       ...
# 495         495   49  ...                          0                         0
# 496         496   24  ...                          1                         0
# 497         497   34  ...                          0                         0
# 498         498   26  ...                          0                         0
# 499         499   26  ...                          0                         0
#
# [500 rows x 521 columns]

# %%
df['satisfied'].hist()

# %%
imbalance=len(df[df['satisfied']==1])/len(df['satisfied'])*100
imbalance
# Out:
# 52.6

# %%
y=df['satisfied'].copy()
x=df.drop(['satisfied'],axis=1)
print(f'Distribution before imbalancing: {Counter(y)}')
X_res, y_res = make_imbalance(x, y,
                              sampling_strategy={0: 142, 1: 263},
                              random_state=42)
print(f'Distribution after imbalancing: {Counter(y_res)}')
# Out:
# Distribution before imbalancing: Counter({1: 263, 0: 237})
# Distribution after imbalancing: Counter({1: 263, 0: 142})

# %%
y_res.hist()  #65% imbalance

# %%
y=df['satisfied'].copy()
x=df.drop(['satisfied'],axis=1)
print(f'Distribution before imbalancing: {Counter(y)}')
X_res, y_res = make_imbalance(x, y,
                              sampling_strategy={0: 88, 1: 263},
                              random_state=42)
print(f'Distribution after imbalancing: {Counter(y_res)}')

# %%
y_res.hist() # 75 percent imbalance

# %%
y=df['satisfied'].copy()
x=df.drop(['satisfied'],axis=1)
print(f'Distribution before imbalancing: {Counter(y)}')
X_res, y_res = make_imbalance(x, y,
                              sampling_strategy={0: 277, 1: 263},
                              random_state=42)
print(f'Distribution after imbalancing: {Counter(y_res)}')

# %%
y_res.hist() #90 percent imbalance
